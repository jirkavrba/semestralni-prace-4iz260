// %%
%use s2

// %%
val apps = DataFrame.readCSV("https://raw.githubusercontent.com/jirkavrba/semestralni-prace-4iz260/main/data/bigml/apps.csv")
val reviews = DataFrame.readCSV("https://raw.githubusercontent.com/jirkavrba/semestralni-prace-4iz260/main/data/bigml/reviews.csv")

// %%
apps
// Out:
// <html><body><table><tr><th style="text-align:left">App</th><th style="text-align:left">Category</th><th style="text-align:left">Rating</th><th style="text-align:left">Reviews</th><th style="text-align:left">Size</th><th style="text-align:left">Installs</th><th style="text-align:left">Type</th><th style="text-align:left">Price</th><th style="text-align:left">Content Rating</th><th style="text-align:left">Genres</th><th style="text-align:left">Last Updated</th><th style="text-align:left">Current Ver</th><th style="text-align:left">Android Ver</th></tr><tr><td style="text-align:left" title="Photo Editor & Candy Camera & Grid & ScrapBook">Photo Editor & Candy Camera & Grid & ScrapBook</td><td style="text-align:left" title="ART_AND_DESIGN">ART_AND_DESIGN</td><td style="text-align:left" title="4.1">4.1</td><td style="text-align:left" title="159">159</td><td style="text-align:left" title="19M">19M</td><td style="text-align:left" title="10,000+">10,000+</td><td style="text-align:left" title
// ...
